# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
smart = pd.read_csv("C:/Users/My Pc/Desktop/Data_Analytics_Course/Power_BI/Supermarket/Supermarket_data.csv", header=2)
smart.head()
# Out:
#     Invoice ID Branch       City Customer - Gender            Product line  \
# 0          NaN    NaN        NaN               NaN                     NaN
# 1          NaN    NaN        NaN               NaN                     NaN
# 2  750-67-8428      A     Yangon     Member-Female       HEALTH AND BEAUTY
# 3  226-31-3081      C  Naypyitaw     Normal-Female  Electronic accessories
# 4  631-41-3108      A     Yangon       Normal-Male      Home and lifestyle
#
#     Unit price  Quantity   Tax 5%     Total        Date  Column2   Time  \
# 0          NaN       NaN      NaN       NaN         NaN      NaN    NaN
# 1          NaN       NaN      NaN       NaN         NaN      NaN    NaN
# 2  74.69 price       7.0  26.1415  548.9715  01-05-2019      NaN  13:08
# 3  15.28 price       5.0   3.8200   80.2200  03-08-2019      NaN  10:29
# 4  46.33 price       7.0  16.2155  340.5255  03-03-2019      NaN  13:23
#
#        Payment    cogs  gross margin percentage  gross income  Rating
# ...

# %%
smart = smart.dropna(how="all",axis=0)

# %%
smart = smart.dropna(how="all",axis=1)

# %%
smart.head()
# Out:
#     Invoice ID Branch       City Customer - Gender            Product line  \
# 2  750-67-8428      A     Yangon     Member-Female       HEALTH AND BEAUTY
# 3  226-31-3081      C  Naypyitaw     Normal-Female  Electronic accessories
# 4  631-41-3108      A     Yangon       Normal-Male      Home and lifestyle
# 5  123-19-1176      A     Yangon       Member-Male       HEALTH AND BEAUTY
# 6  373-73-7910      A     Yangon       Normal-Male       Sports and travel
#
#     Unit price  Quantity   Tax 5%     Total        Date   Time      Payment  \
# 2  74.69 price       7.0  26.1415  548.9715  01-05-2019  13:08      Ewallet
# 3  15.28 price       5.0   3.8200   80.2200  03-08-2019  10:29         Cash
# 4  46.33 price       7.0  16.2155  340.5255  03-03-2019  13:23  Credit card
# 5  58.22 price       8.0  23.2880  489.0480   1/27/2019  20:33      Ewallet
# 6  86.31 price       7.0  30.2085  634.3785  02-08-2019  10:37      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating
# ...

# %%
smart[['Customer','Gender']] = smart['Customer - Gender'].str.split('-',expand=True)

# %%
smart.head()
# Out:
#     Invoice ID Branch       City Customer - Gender            Product line  \
# 2  750-67-8428      A     Yangon     Member-Female       HEALTH AND BEAUTY
# 3  226-31-3081      C  Naypyitaw     Normal-Female  Electronic accessories
# 4  631-41-3108      A     Yangon       Normal-Male      Home and lifestyle
# 5  123-19-1176      A     Yangon       Member-Male       HEALTH AND BEAUTY
# 6  373-73-7910      A     Yangon       Normal-Male       Sports and travel
#
#     Unit price  Quantity   Tax 5%     Total        Date   Time      Payment  \
# 2  74.69 price       7.0  26.1415  548.9715  01-05-2019  13:08      Ewallet
# 3  15.28 price       5.0   3.8200   80.2200  03-08-2019  10:29         Cash
# 4  46.33 price       7.0  16.2155  340.5255  03-03-2019  13:23  Credit card
# 5  58.22 price       8.0  23.2880  489.0480   1/27/2019  20:33      Ewallet
# 6  86.31 price       7.0  30.2085  634.3785  02-08-2019  10:37      Ewallet
#
# ...

# %%
smart = smart.drop(columns =['Customer - Gender'])

# %%
smart.head()
# Out:
#     Invoice ID Branch       City            Product line   Unit price  \
# 2  750-67-8428      A     Yangon       HEALTH AND BEAUTY  74.69 price
# 3  226-31-3081      C  Naypyitaw  Electronic accessories  15.28 price
# 4  631-41-3108      A     Yangon      Home and lifestyle  46.33 price
# 5  123-19-1176      A     Yangon       HEALTH AND BEAUTY  58.22 price
# 6  373-73-7910      A     Yangon       Sports and travel  86.31 price
#
#    Quantity   Tax 5%     Total        Date   Time      Payment    cogs  \
# 2       7.0  26.1415  548.9715  01-05-2019  13:08      Ewallet  522.83
# 3       5.0   3.8200   80.2200  03-08-2019  10:29         Cash   76.40
# 4       7.0  16.2155  340.5255  03-03-2019  13:23  Credit card  324.31
# 5       8.0  23.2880  489.0480   1/27/2019  20:33      Ewallet  465.76
# 6       7.0  30.2085  634.3785  02-08-2019  10:37      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating Customer  Gender
# ...

# %%
smart[['Unit','Price']] = smart['Unit price'].str.split(' ',expand=True)

# %%
smart.head()
# Out:
#     Invoice ID Branch       City            Product line   Unit price  \
# 2  750-67-8428      A     Yangon       HEALTH AND BEAUTY  74.69 price
# 3  226-31-3081      C  Naypyitaw  Electronic accessories  15.28 price
# 4  631-41-3108      A     Yangon      Home and lifestyle  46.33 price
# 5  123-19-1176      A     Yangon       HEALTH AND BEAUTY  58.22 price
# 6  373-73-7910      A     Yangon       Sports and travel  86.31 price
#
#    Quantity   Tax 5%     Total        Date   Time      Payment    cogs  \
# 2       7.0  26.1415  548.9715  01-05-2019  13:08      Ewallet  522.83
# 3       5.0   3.8200   80.2200  03-08-2019  10:29         Cash   76.40
# 4       7.0  16.2155  340.5255  03-03-2019  13:23  Credit card  324.31
# 5       8.0  23.2880  489.0480   1/27/2019  20:33      Ewallet  465.76
# 6       7.0  30.2085  634.3785  02-08-2019  10:37      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating Customer  Gender   Unit  \
# ...

# %%
smart = smart.drop(columns=['Unit price'])

# %%
smart = smart.drop(columns=['Price'])

# %%
smart.head()
# Out:
#     Invoice ID Branch       City            Product line  Quantity   Tax 5%  \
# 2  750-67-8428      A     Yangon       HEALTH AND BEAUTY       7.0  26.1415
# 3  226-31-3081      C  Naypyitaw  Electronic accessories       5.0   3.8200
# 4  631-41-3108      A     Yangon      Home and lifestyle       7.0  16.2155
# 5  123-19-1176      A     Yangon       HEALTH AND BEAUTY       8.0  23.2880
# 6  373-73-7910      A     Yangon       Sports and travel       7.0  30.2085
#
#       Total        Date   Time      Payment    cogs  gross margin percentage  \
# 2  548.9715  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 3   80.2200  03-08-2019  10:29         Cash   76.40                 4.761905
# 4  340.5255  03-03-2019  13:23  Credit card  324.31                 4.761905
# 5  489.0480   1/27/2019  20:33      Ewallet  465.76                 4.761905
# 6  634.3785  02-08-2019  10:37      Ewallet  604.17                 4.761905
#
# ...

# %%
smart['Product line'] = smart['Product line'].replace('HEALTH AND BEAUTY','Health and Beauty')

# %%
smart.head()
# Out:
#     Invoice ID Branch       City            Product line  Quantity   Tax 5%  \
# 2  750-67-8428      A     Yangon       Health and Beauty       7.0  26.1415
# 3  226-31-3081      C  Naypyitaw  Electronic accessories       5.0   3.8200
# 4  631-41-3108      A     Yangon      Home and lifestyle       7.0  16.2155
# 5  123-19-1176      A     Yangon       Health and Beauty       8.0  23.2880
# 6  373-73-7910      A     Yangon       Sports and travel       7.0  30.2085
#
#       Total        Date   Time      Payment    cogs  gross margin percentage  \
# 2  548.9715  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 3   80.2200  03-08-2019  10:29         Cash   76.40                 4.761905
# 4  340.5255  03-03-2019  13:23  Credit card  324.31                 4.761905
# 5  489.0480   1/27/2019  20:33      Ewallet  465.76                 4.761905
# 6  634.3785  02-08-2019  10:37      Ewallet  604.17                 4.761905
#
# ...

# %%
smart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2 to 1005
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Product line             1000 non-null   object
#  4   Quantity                 1000 non-null   float64
#  5   Tax 5%                   1000 non-null   float64
#  6   Total                    1000 non-null   float64
#  7   Date                     1000 non-null   object
#  8   Time                     1000 non-null   object
#  9   Payment                  1000 non-null   object
#  10  cogs                     1000 non-null   float64
#  11  gross margin percentage  1000 non-null   float64
#  12  gross income             1000 non-null   float64
#  13  Rating                   1000 non-null   float64
# ...

# %%
smart['Invoice ID'] = smart['Invoice ID'].astype('string')

# %%
smart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2 to 1005
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   string
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Product line             1000 non-null   object
#  4   Quantity                 1000 non-null   float64
#  5   Tax 5%                   1000 non-null   float64
#  6   Total                    1000 non-null   float64
#  7   Date                     1000 non-null   object
#  8   Time                     1000 non-null   object
#  9   Payment                  1000 non-null   object
#  10  cogs                     1000 non-null   float64
#  11  gross margin percentage  1000 non-null   float64
#  12  gross income             1000 non-null   float64
#  13  Rating                   1000 non-null   float64
# ...

# %%
smart['Branch'] = smart['Branch'].astype('string')
smart['City'] = smart['City'].astype('string')
smart['Product line'] = smart['Product line'].astype('string')
smart['Payment'] = smart['Payment'].astype('string')
smart['Customer'] = smart['Customer'].astype('string')
smart['Gender'] = smart['Gender'].astype('string')
smart['Unit'] = smart['Unit'].astype('float')

# %%
smart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2 to 1005
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   string
#  1   Branch                   1000 non-null   string
#  2   City                     1000 non-null   string
#  3   Product line             1000 non-null   string
#  4   Quantity                 1000 non-null   float64
#  5   Tax 5%                   1000 non-null   float64
#  6   Total                    1000 non-null   float64
#  7   Date                     1000 non-null   object
#  8   Time                     1000 non-null   object
#  9   Payment                  1000 non-null   string
#  10  cogs                     1000 non-null   float64
#  11  gross margin percentage  1000 non-null   float64
#  12  gross income             1000 non-null   float64
#  13  Rating                   1000 non-null   float64
# ...
