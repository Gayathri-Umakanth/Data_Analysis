# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
import pandas as pd
import numpy as np

#location = "C:/Users/My Pc/Desktop/Data_Analytics_Course/Power_BI/Sales/Sales_data.csv"
sales1 = pd.read_csv("C:/Users/My Pc/Desktop/Data_Analytics_Course/Power_BI/Sales/Sales_data.csv", header=2)

# %%
sales1.head(5)
# Out:
#    order_id (unique) product_id  column3 store_id order_date order_date_2  \
# 0                NaN        NaN      NaN      NaN        NaN          NaN
# 1                1.0      P0258      NaN    S0008   1/2/2017     2-Jan-17
# 2                NaN        NaN      NaN      NaN        NaN          NaN
# 3                NaN        NaN      NaN      NaN        NaN          NaN
# 4                2.0      P0348      NaN    S0110   1/2/2017     2-Jan-17
#
#      sales  revenue  stock  price promo_type_1 promo_bin_1 promo_type_2  \
# 0      NaN      NaN    NaN    NaN          NaN         NaN          NaN
# 1  0 sales      0.0    5.0    6.5         PR14         NaN         PR03
# 2      NaN      NaN    NaN    NaN          NaN         NaN          NaN
# 3      NaN      NaN    NaN    NaN          NaN         NaN          NaN
# 4  0 sales      0.0    9.0    2.1         PR05     verylow         PR03
#
#    promo_bin_2  promo_discount_2 delivery_date_format1 delivery_date_format2
# ...

# %%
sales1 = sales1.loc[1:]

# %%
sales1.head()
# Out:
#    order_id (unique) product_id  column3 store_id order_date order_date_2  \
# 1                1.0      P0258      NaN    S0008   1/2/2017     2-Jan-17
# 2                NaN        NaN      NaN      NaN        NaN          NaN
# 3                NaN        NaN      NaN      NaN        NaN          NaN
# 4                2.0      P0348      NaN    S0110   1/2/2017     2-Jan-17
# 5                NaN        NaN      NaN      NaN        NaN          NaN
#
#      sales  revenue  stock  price promo_type_1 promo_bin_1 promo_type_2  \
# 1  0 sales      0.0    5.0    6.5         PR14         NaN         PR03
# 2      NaN      NaN    NaN    NaN          NaN         NaN          NaN
# 3      NaN      NaN    NaN    NaN          NaN         NaN          NaN
# 4  0 sales      0.0    9.0    2.1         PR05     verylow         PR03
# 5      NaN      NaN    NaN    NaN          NaN         NaN          NaN
#
#    promo_bin_2  promo_discount_2 delivery_date_format1 delivery_date_format2
# ...

# %%
sales1 = sales1.dropna(how="all",axis=0)

# %%
sales1.head()
# Out:
#    order_id (unique) product_id  column3 store_id order_date order_date_2  \
# 1                1.0      P0258      NaN    S0008   1/2/2017     2-Jan-17
# 4                2.0      P0348      NaN    S0110   1/2/2017     2-Jan-17
# 6                3.0      P0219      NaN    S0026   1/2/2017     2-Jan-17
# 7                3.0      P0219      NaN    S0026   1/2/2017     2-Jan-17
# 8                3.0      P0219      NaN    S0026   1/2/2017     2-Jan-17
#
#      sales  revenue  stock  price promo_type_1 promo_bin_1 promo_type_2  \
# 1  0 sales     0.00    5.0   6.50         PR14         NaN         PR03
# 4  0 sales     0.00    9.0   2.10         PR05     verylow         PR03
# 6  5 sales    33.56    3.0   7.25         PR14         NaN         PR03
# 7  5 sales    33.56    3.0   7.25         PR14         NaN         PR03
# 8  5 sales    33.56    3.0   7.25         PR14         NaN         PR03
#
#    promo_bin_2  promo_discount_2 delivery_date_format1 delivery_date_format2
# ...

# %%
sales1 = sales1.dropna(how="all",axis=1)

# %%
sales1.head(10)
# Out:
#     order_id (unique) product_id store_id order_date order_date_2    sales  \
# 1                 1.0      P0258    S0008   1/2/2017     2-Jan-17  0 sales
# 4                 2.0      P0348    S0110   1/2/2017     2-Jan-17  0 sales
# 6                 3.0      P0219    S0026   1/2/2017     2-Jan-17  5 sales
# 7                 3.0      P0219    S0026   1/2/2017     2-Jan-17  5 sales
# 8                 3.0      P0219    S0026   1/2/2017     2-Jan-17  5 sales
# 10                4.0      P0218    S0051   1/2/2017     2-Jan-17  0 sales
# 11                5.0      P0660    S0056   1/2/2017     2-Jan-17  1 sales
# 12                6.0      P0695    S0023   1/2/2017     2-Jan-17  0 sales
# 13                7.0      P0695    S0132   1/2/2017     2-Jan-17  0 sales
# 14                8.0      P0296    S0004   1/2/2017     2-Jan-17  0 sales
#
#     revenue  stock  price promo_type_1 promo_bin_1 promo_type_2  \
# 1      0.00    5.0   6.50         PR14         NaN         PR03
# ...

# %%
sales1.drop_duplicates()
# Out:
#        order_id (unique) product_id store_id  order_date order_date_2  \
# 1                    1.0      P0258    S0008    1/2/2017     2-Jan-17
# 4                    2.0      P0348    S0110    1/2/2017     2-Jan-17
# 6                    3.0      P0219    S0026    1/2/2017     2-Jan-17
# 10                   4.0      P0218    S0051    1/2/2017     2-Jan-17
# 11                   5.0      P0660    S0056    1/2/2017     2-Jan-17
# ...                  ...        ...      ...         ...          ...
# 18119            18113.0      P0348    S0065  12/31/2017    31-Dec-17
# 18120            18114.0      P0585    S0096  12/31/2017    31-Dec-17
# 18121            18115.0      P0223    S0048  12/31/2017    31-Dec-17
# 18122            18116.0      P0664    S0113  12/31/2017    31-Dec-17
# 18123            18117.0      P0582    S0038  12/31/2017    31-Dec-17
#
#          sales  revenue  stock  price promo_type_1 promo_bin_1 promo_type_2  \
# ...

# %%
sales1.fillna('Null')
# Out:
#        order_id (unique) product_id store_id  order_date order_date_2  \
# 1                    1.0      P0258    S0008    1/2/2017     2-Jan-17
# 4                    2.0      P0348    S0110    1/2/2017     2-Jan-17
# 6                    3.0      P0219    S0026    1/2/2017     2-Jan-17
# 7                    3.0      P0219    S0026    1/2/2017     2-Jan-17
# 8                    3.0      P0219    S0026    1/2/2017     2-Jan-17
# ...                  ...        ...      ...         ...          ...
# 18119            18113.0      P0348    S0065  12/31/2017    31-Dec-17
# 18120            18114.0      P0585    S0096  12/31/2017    31-Dec-17
# 18121            18115.0      P0223    S0048  12/31/2017    31-Dec-17
# 18122            18116.0      P0664    S0113  12/31/2017    31-Dec-17
# 18123            18117.0      P0582    S0038  12/31/2017    31-Dec-17
#
#          sales revenue stock  price promo_type_1 promo_bin_1 promo_type_2  \
# ...

# %%
sales1= sales1.rename(columns = {"order_id (unique)" : "order_id"})

# %%
sales1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18119 entries, 1 to 18123
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               18119 non-null  float64
#  1   product_id             18117 non-null  object
#  2   store_id               18117 non-null  object
#  3   order_date             18117 non-null  object
#  4   order_date_2           18117 non-null  object
#  5   sales                  18117 non-null  object
#  6   revenue                18117 non-null  float64
#  7   stock                  18117 non-null  float64
#  8   price                  17493 non-null  float64
#  9   promo_type_1           18117 non-null  object
#  10  promo_bin_1            1993 non-null   object
#  11  promo_type_2           18117 non-null  object
#  12  delivery_date_format1  18117 non-null  object
#  13  delivery_date_format2  18117 non-null  object
# dtypes: float64(4), object(10)
# ...

# %%
sales1['order_id'] = sales1['order_id'].fillna(0).astype(int)

# %%
sales1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18119 entries, 1 to 18123
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               18119 non-null  int64
#  1   product_id             18117 non-null  object
#  2   store_id               18117 non-null  object
#  3   order_date             18117 non-null  object
#  4   order_date_2           18117 non-null  object
#  5   sales                  18117 non-null  object
#  6   revenue                18117 non-null  float64
#  7   stock                  18117 non-null  float64
#  8   price                  17493 non-null  float64
#  9   promo_type_1           18117 non-null  object
#  10  promo_bin_1            1993 non-null   object
#  11  promo_type_2           18117 non-null  object
#  12  delivery_date_format1  18117 non-null  object
#  13  delivery_date_format2  18117 non-null  object
# ...

# %%
sales1.head()
# Out:
#    order_id product_id store_id order_date order_date_2    sales  revenue  \
# 1         1      P0258    S0008   1/2/2017     2-Jan-17  0 sales     0.00
# 4         2      P0348    S0110   1/2/2017     2-Jan-17  0 sales     0.00
# 6         3      P0219    S0026   1/2/2017     2-Jan-17  5 sales    33.56
# 7         3      P0219    S0026   1/2/2017     2-Jan-17  5 sales    33.56
# 8         3      P0219    S0026   1/2/2017     2-Jan-17  5 sales    33.56
#
#    stock  price promo_type_1 promo_bin_1 promo_type_2 delivery_date_format1  \
# 1    5.0   6.50         PR14         NaN         PR03              1/5/2017
# 4    9.0   2.10         PR05     verylow         PR03              1/4/2017
# 6    3.0   7.25         PR14         NaN         PR03              1/5/2017
# 7    3.0   7.25         PR14         NaN         PR03              1/5/2017
# 8    3.0   7.25         PR14         NaN         PR03              1/5/2017
#
#   delivery_date_format2
# 1              5/1/2017
# ...

# %%
sales1[['sales','data']] = sales1['sales'].str.split(' ', expand=True)

# %%
sales1.head()
# Out:
#    order_id product_id store_id order_date order_date_2 sales  revenue  stock  \
# 1         1      P0258    S0008   1/2/2017     2-Jan-17     0     0.00    5.0
# 4         2      P0348    S0110   1/2/2017     2-Jan-17     0     0.00    9.0
# 6         3      P0219    S0026   1/2/2017     2-Jan-17     5    33.56    3.0
# 7         3      P0219    S0026   1/2/2017     2-Jan-17     5    33.56    3.0
# 8         3      P0219    S0026   1/2/2017     2-Jan-17     5    33.56    3.0
#
#    price promo_type_1 promo_bin_1 promo_type_2 delivery_date_format1  \
# 1   6.50         PR14         NaN         PR03              1/5/2017
# 4   2.10         PR05     verylow         PR03              1/4/2017
# 6   7.25         PR14         NaN         PR03              1/5/2017
# 7   7.25         PR14         NaN         PR03              1/5/2017
# 8   7.25         PR14         NaN         PR03              1/5/2017
#
#   delivery_date_format2   data
# 1              5/1/2017  sales
# ...

# %%
sales1 = sales1.drop(columns=['data'])

# %%
sales1.head()
# Out:
#    order_id product_id store_id order_date order_date_2 sales  revenue  stock  \
# 1         1      P0258    S0008   1/2/2017     2-Jan-17     0     0.00    5.0
# 4         2      P0348    S0110   1/2/2017     2-Jan-17     0     0.00    9.0
# 6         3      P0219    S0026   1/2/2017     2-Jan-17     5    33.56    3.0
# 7         3      P0219    S0026   1/2/2017     2-Jan-17     5    33.56    3.0
# 8         3      P0219    S0026   1/2/2017     2-Jan-17     5    33.56    3.0
#
#    price promo_type_1 promo_bin_1 promo_type_2 delivery_date_format1  \
# 1   6.50         PR14         NaN         PR03              1/5/2017
# 4   2.10         PR05     verylow         PR03              1/4/2017
# 6   7.25         PR14         NaN         PR03              1/5/2017
# 7   7.25         PR14         NaN         PR03              1/5/2017
# 8   7.25         PR14         NaN         PR03              1/5/2017
#
#   delivery_date_format2
# 1              5/1/2017
# 4              4/1/2017
# ...

# %%
sales2 = pd.read_csv("C:/Users/My Pc/Desktop/Data_Analytics_Course/Power_BI/Sales/Product_data.csv")

# %%
sales2.head()
# Out:
#   product_id                              product (brand)  \
# 0      P0000                            \tserum\t (Livon)
# 1      P0001       hand wash -\t moisture Shield (Savlon)
# 2      P0002      good \t\tday butter Cookies (Britannia)
# 3      P0004   Happy \t\tHappy Choco-Chip Cookies (Parle)
# 4      P0005   50-50 Timepass salted biscuits (Britannia)
#
#                       type length x depth x width (in cm)  \
# 0    Indian & Exotic Herbs                    5 x 20 x 12
# 1         Hair Oil & Serum                 13.5 x 22 x 20
# 2   Hand Wash & Sanitizers                   22 x 40 x 22
# 3                  Cookies                     2 x 13 x 4
# 4  Glucose & Milk Biscuits                   16 x 30 x 16
#
#                        category || sub_category
# 0     Fruits & Vegetables || Herbs & Seasonings
# 1                 Beauty & Hygiene || Hair Care
# 2          Beauty & Hygiene || Bath & Hand Wash
# 3  Snacks & Branded Foods || Biscuits & Cookies
# ...

# %%
sales2[['length','depth','width']] = sales2['length x depth x width (in cm)'].str.split(' x ', expand=True)

# %%
sales2.head()
# Out:
#   product_id                              product (brand)  \
# 0      P0000                            \tserum\t (Livon)
# 1      P0001       hand wash -\t moisture Shield (Savlon)
# 2      P0002      good \t\tday butter Cookies (Britannia)
# 3      P0004   Happy \t\tHappy Choco-Chip Cookies (Parle)
# 4      P0005   50-50 Timepass salted biscuits (Britannia)
#
#                       type length x depth x width (in cm)  \
# 0    Indian & Exotic Herbs                    5 x 20 x 12
# 1         Hair Oil & Serum                 13.5 x 22 x 20
# 2   Hand Wash & Sanitizers                   22 x 40 x 22
# 3                  Cookies                     2 x 13 x 4
# 4  Glucose & Milk Biscuits                   16 x 30 x 16
#
#                        category || sub_category length depth width
# 0     Fruits & Vegetables || Herbs & Seasonings      5    20    12
# 1                 Beauty & Hygiene || Hair Care   13.5    22    20
# ...

# %%
sales2 = sales2.drop(columns=['length x depth x width (in cm)'])

# %%
sales2.head()
# Out:
#   product_id                              product (brand)  \
# 0      P0000                            \tserum\t (Livon)
# 1      P0001       hand wash -\t moisture Shield (Savlon)
# 2      P0002      good \t\tday butter Cookies (Britannia)
# 3      P0004   Happy \t\tHappy Choco-Chip Cookies (Parle)
# 4      P0005   50-50 Timepass salted biscuits (Britannia)
#
#                       type                      category || sub_category  \
# 0    Indian & Exotic Herbs     Fruits & Vegetables || Herbs & Seasonings
# 1         Hair Oil & Serum                 Beauty & Hygiene || Hair Care
# 2   Hand Wash & Sanitizers          Beauty & Hygiene || Bath & Hand Wash
# 3                  Cookies  Snacks & Branded Foods || Biscuits & Cookies
# 4  Glucose & Milk Biscuits  Snacks & Branded Foods || Biscuits & Cookies
#
#   length depth width
# 0      5    20    12
# 1   13.5    22    20
# 2     22    40    22
# 3      2    13     4
# 4     16    30    16

# %%
import pandas as pd
sales3 = pd.read_csv("C:/Users/My Pc/Desktop/Data_Analytics_Course/Power_BI/Sales/Stores_data.csv", encoding='latin1')

# %%
sales3.head()
# Out:
#   store_id storetype_id store_szie city_id  \
# 0    S0091         ST04      19 m²    C013
# 1    S0012         ST04      28 m²    C005
# 2    S0045         ST04      17 qm    C008
# 3    S0032         ST03      14 m²    C019
# 4    S0027         ST04      24 qm    C022
#
#                     state - state abr - city           lat / long
# 0  AR - Arkansas - Hot Springs National Park   34.5137 / -92.9685
# 1                    TX - Texas - Huntsville   30.7813 / -95.5953
# 2            NC - North Carolina - Asheville   35.6004 / -82.4918
# 3              CA - California - Los Angeles  33.7866 / -118.2987
# 4                     TX - Texas - Texarkana   33.3934 / -94.3404

# %%
sales3[['store_size','data']] = sales3['store_szie'].str.split(' ', expand=True)

# %%
sales3.head()
# Out:
#   store_id storetype_id store_szie city_id  \
# 0    S0091         ST04      19 m²    C013
# 1    S0012         ST04      28 m²    C005
# 2    S0045         ST04      17 qm    C008
# 3    S0032         ST03      14 m²    C019
# 4    S0027         ST04      24 qm    C022
#
#                     state - state abr - city           lat / long store_size  \
# 0  AR - Arkansas - Hot Springs National Park   34.5137 / -92.9685         19
# 1                    TX - Texas - Huntsville   30.7813 / -95.5953         28
# 2            NC - North Carolina - Asheville   35.6004 / -82.4918         17
# 3              CA - California - Los Angeles  33.7866 / -118.2987         14
# 4                     TX - Texas - Texarkana   33.3934 / -94.3404         24
#
#   data
# 0   m²
# 1   m²
# 2   qm
# 3   m²
# 4   qm

# %%
sales3 = sales3.drop(columns=['store_szie'])

# %%
sales3 = sales3.drop(columns=['data'])

# %%
sales3[['lat','long']] = sales3['lat / long'].str.split('/', expand = True)

# %%
sales3 = sales3.drop(columns=['lat / long'])

# %%
sales3.head()
# Out:
#   store_id storetype_id city_id                   state - state abr - city  \
# 0    S0091         ST04    C013  AR - Arkansas - Hot Springs National Park
# 1    S0012         ST04    C005                    TX - Texas - Huntsville
# 2    S0045         ST04    C008            NC - North Carolina - Asheville
# 3    S0032         ST03    C019              CA - California - Los Angeles
# 4    S0027         ST04    C022                     TX - Texas - Texarkana
#
#   store_size       lat        long
# 0         19  34.5137     -92.9685
# 1         28  30.7813     -95.5953
# 2         17  35.6004     -82.4918
# 3         14  33.7866    -118.2987
# 4         24  33.3934     -94.3404

# %%
sales4 = pd.read_excel("C:/Users/My Pc/Desktop/Data_Analytics_Course/Power_BI/Sales/Store_costs.xlsx")

# %%
sales4.head()
# Out:
#   store_id  building-costs  land and devolopment costs  Other related costs
# 0    S0091       3467959.0                     1180964               421335
# 1    S0012       2205562.0                      744172               316866
# 2    S0045        498766.0                      170288                56093
# 3    S0032       7750009.0                     2585892              1216210
# 4    S0027       1338071.0                      444113               191515

# %%
sales5 = pd.read_csv("C:/Users/My Pc/Desktop/Data_Analytics_Course/Power_BI/Sales/Sales_data_2018.csv")

# %%
sales5.head()
# Out:
#    order_id product_id store_id order_date order_date_2  sales  revenue  \
# 0     18117      P0129    S0030   1/1/2018     1-Jan-18    0.0      0.0
# 1     18118      P0513    S0108   1/1/2018     1-Jan-18    0.0      0.0
# 2     18119      P0229    S0069   1/1/2018     1-Jan-18    0.0      0.0
# 3     18120      P0275    S0065   1/1/2018     1-Jan-18    0.0      0.0
# 4     18121      P0427    S0098   1/1/2018     1-Jan-18    0.0      0.0
#
#    stock  price promo_type_1 promo_bin_1 promo_type_2  promo_bin_2  \
# 0    3.0  24.95         PR14         NaN         PR03          NaN
# 1    6.0  15.00         PR14         NaN         PR03          NaN
# 2    3.0   7.95         PR14         NaN         PR03          NaN
# 3   39.0   2.45         PR14         NaN         PR03          NaN
# 4    1.0    NaN         PR14         NaN         PR03          NaN
#
#    promo_discount_2 delivery_date_format1 delivery_date_format2
# 0               NaN              1/4/2018              4/1/2018
# ...

# %%
sales5 = sales5.dropna(how="all", axis=1)

# %%
sales5.head()
# Out:
#    order_id product_id store_id order_date order_date_2  sales  revenue  \
# 0     18117      P0129    S0030   1/1/2018     1-Jan-18    0.0      0.0
# 1     18118      P0513    S0108   1/1/2018     1-Jan-18    0.0      0.0
# 2     18119      P0229    S0069   1/1/2018     1-Jan-18    0.0      0.0
# 3     18120      P0275    S0065   1/1/2018     1-Jan-18    0.0      0.0
# 4     18121      P0427    S0098   1/1/2018     1-Jan-18    0.0      0.0
#
#    stock  price promo_type_1 promo_bin_1 promo_type_2 delivery_date_format1  \
# 0    3.0  24.95         PR14         NaN         PR03              1/4/2018
# 1    6.0  15.00         PR14         NaN         PR03              1/4/2018
# 2    3.0   7.95         PR14         NaN         PR03              1/4/2018
# 3   39.0   2.45         PR14         NaN         PR03              1/5/2018
# 4    1.0    NaN         PR14         NaN         PR03              1/2/2018
#
#   delivery_date_format2
# 0              4/1/2018
# 1              4/1/2018
# ...

# %%
sales5 = sales5.fillna('Null')

# %%
sales5.head()
# Out:
#    order_id product_id store_id order_date order_date_2  sales  revenue  \
# 0     18117      P0129    S0030   1/1/2018     1-Jan-18    0.0      0.0
# 1     18118      P0513    S0108   1/1/2018     1-Jan-18    0.0      0.0
# 2     18119      P0229    S0069   1/1/2018     1-Jan-18    0.0      0.0
# 3     18120      P0275    S0065   1/1/2018     1-Jan-18    0.0      0.0
# 4     18121      P0427    S0098   1/1/2018     1-Jan-18    0.0      0.0
#
#    stock  price promo_type_1 promo_bin_1 promo_type_2 delivery_date_format1  \
# 0    3.0  24.95         PR14        Null         PR03              1/4/2018
# 1    6.0   15.0         PR14        Null         PR03              1/4/2018
# 2    3.0   7.95         PR14        Null         PR03              1/4/2018
# 3   39.0   2.45         PR14        Null         PR03              1/5/2018
# 4    1.0   Null         PR14        Null         PR03              1/2/2018
#
#   delivery_date_format2
# 0              4/1/2018
# 1              4/1/2018
# ...

# %%
sales5 = sales5.drop(columns='order_date_2')

# %%
sales5 = sales5.drop(columns='delivery_date_format2')

# %%
sales5.head()
# Out:
#    order_id product_id store_id order_date  sales  revenue  stock  price  \
# 0     18117      P0129    S0030   1/1/2018    0.0      0.0    3.0  24.95
# 1     18118      P0513    S0108   1/1/2018    0.0      0.0    6.0   15.0
# 2     18119      P0229    S0069   1/1/2018    0.0      0.0    3.0   7.95
# 3     18120      P0275    S0065   1/1/2018    0.0      0.0   39.0   2.45
# 4     18121      P0427    S0098   1/1/2018    0.0      0.0    1.0   Null
#
#   promo_type_1 promo_bin_1 promo_type_2 delivery_date_format1
# 0         PR14        Null         PR03              1/4/2018
# 1         PR14        Null         PR03              1/4/2018
# 2         PR14        Null         PR03              1/4/2018
# 3         PR14        Null         PR03              1/5/2018
# 4         PR14        Null         PR03              1/2/2018

# %%
sales6 = pd.read_csv("C:/Users/My Pc/Desktop/Data_Analytics_Course/Power_BI/Sales/Sales_data_2019.csv")

# %%
sales6.head()
# Out:
#    order_id product_id store_id order_date order_date_2  sales  revenue  \
# 0     40911      P0392    S0001   1/1/2019     1-Jan-19    0.0     0.00
# 1     40912      P0018    S0071   1/1/2019     1-Jan-19    0.0     0.00
# 2     40913      P0565    S0096   1/1/2019     1-Jan-19    0.0     0.00
# 3     40914      P0372    S0121   1/1/2019     1-Jan-19    0.0     0.00
# 4     40915      P0543    S0101   1/1/2019     1-Jan-19    2.0     7.41
#
#    stock   price promo_type_1 promo_bin_1 promo_type_2 promo_bin_2  \
# 0    3.0  124.99         PR14         NaN         PR03         NaN
# 1    4.0    3.25         PR03     verylow         PR03         NaN
# 2   12.0    4.25         PR14         NaN         PR03         NaN
# 3   24.0    4.90         PR14         NaN         PR03         NaN
# 4   11.0    4.00         PR14         NaN         PR03         NaN
#
#    promo_discount_2 delivery_date_format1 delivery_date_format2
# 0               NaN              1/3/2019              3/1/2019
# ...

# %%
sales6 = sales6.dropna(how="all", axis=1)

# %%
sales6.head()
# Out:
#    order_id product_id store_id order_date order_date_2  sales  revenue  \
# 0     40911      P0392    S0001   1/1/2019     1-Jan-19    0.0     0.00
# 1     40912      P0018    S0071   1/1/2019     1-Jan-19    0.0     0.00
# 2     40913      P0565    S0096   1/1/2019     1-Jan-19    0.0     0.00
# 3     40914      P0372    S0121   1/1/2019     1-Jan-19    0.0     0.00
# 4     40915      P0543    S0101   1/1/2019     1-Jan-19    2.0     7.41
#
#    stock   price promo_type_1 promo_bin_1 promo_type_2 promo_bin_2  \
# 0    3.0  124.99         PR14         NaN         PR03         NaN
# 1    4.0    3.25         PR03     verylow         PR03         NaN
# 2   12.0    4.25         PR14         NaN         PR03         NaN
# 3   24.0    4.90         PR14         NaN         PR03         NaN
# 4   11.0    4.00         PR14         NaN         PR03         NaN
#
#    promo_discount_2 delivery_date_format1 delivery_date_format2
# 0               NaN              1/3/2019              3/1/2019
# ...

# %%
sales6 = sales6.drop(columns='promo_bin_2')

# %%
sales6 = sales6.drop(columns='promo_discount_2')

# %%
sales6.head()
# Out:
#    order_id product_id store_id order_date order_date_2  sales  revenue  \
# 0     40911      P0392    S0001   1/1/2019     1-Jan-19    0.0     0.00
# 1     40912      P0018    S0071   1/1/2019     1-Jan-19    0.0     0.00
# 2     40913      P0565    S0096   1/1/2019     1-Jan-19    0.0     0.00
# 3     40914      P0372    S0121   1/1/2019     1-Jan-19    0.0     0.00
# 4     40915      P0543    S0101   1/1/2019     1-Jan-19    2.0     7.41
#
#    stock   price promo_type_1 promo_bin_1 promo_type_2 delivery_date_format1  \
# 0    3.0  124.99         PR14         NaN         PR03              1/3/2019
# 1    4.0    3.25         PR03     verylow         PR03              1/3/2019
# 2   12.0    4.25         PR14         NaN         PR03              1/4/2019
# 3   24.0    4.90         PR14         NaN         PR03              1/3/2019
# 4   11.0    4.00         PR14         NaN         PR03              1/5/2019
#
#   delivery_date_format2
# 0              3/1/2019
# ...

# %%
sales6 = sales6.fillna('Null')

# %%
sales6.head()
# Out:
#    order_id product_id store_id order_date order_date_2 sales revenue stock  \
# 0     40911      P0392    S0001   1/1/2019     1-Jan-19   0.0     0.0   3.0
# 1     40912      P0018    S0071   1/1/2019     1-Jan-19   0.0     0.0   4.0
# 2     40913      P0565    S0096   1/1/2019     1-Jan-19   0.0     0.0  12.0
# 3     40914      P0372    S0121   1/1/2019     1-Jan-19   0.0     0.0  24.0
# 4     40915      P0543    S0101   1/1/2019     1-Jan-19   2.0    7.41  11.0
#
#     price promo_type_1 promo_bin_1 promo_type_2 delivery_date_format1  \
# 0  124.99         PR14        Null         PR03              1/3/2019
# 1    3.25         PR03     verylow         PR03              1/3/2019
# 2    4.25         PR14        Null         PR03              1/4/2019
# 3     4.9         PR14        Null         PR03              1/3/2019
# 4     4.0         PR14        Null         PR03              1/5/2019
#
#   delivery_date_format2
# 0              3/1/2019
# 1              3/1/2019
# ...

# %%
sb.pairplot(data=sales1,palette='bright',diag_kind='hist')
plt.show()
# Out:
# C:\Users\My Pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\My Pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\My Pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\My Pc\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# ...
